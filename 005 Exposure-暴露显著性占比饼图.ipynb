# %%
import matplotlib
import pandas as pd
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os


import seaborn as sns
from matplotlib import rcParams

#绘图前的基本设置

myfont = fm.FontProperties(fname=r'C:\Windows\Fonts\Times New Roman.tiff') # 设置字体

# 设置matplotlib正常显示中文和负号


# matplotlib.rcParams['font.sans-serif']=['NSimSun']   # 用黑体显示中文
# matplotlib.rcParams['axes.unicode_minus']=False     # 正常显示负号
# matplotlib.rcParams['font.size'] = 0.3
# matplotlib.rcParams['font.family'] = 'sans-serif'  
matplotlib.rcParams['font.sans-serif'] = 'Times New Roman'  # NSimSun 新宋体字体   宋体：SimSuncss

# %matplotlib inline  
#内嵌绘图，并且可以省略掉plt.show()这一步
os.chdir(r'E:\BaiduSyncdisk\Futureheatwave\data\exposure')

# %%
alldata = pd.read_csv('Reclassify_Z_age_exposure.csv')

print(alldata)
# Out:
#    Value  TM_245  TM_585  TN_245  TN_585  TX_245  TX_585  Historical  \
# 0      2   43779   37253   35734   37800   39303   41613       79218
# 1      1   19409   15444   41750   31721   42052   39202         267
# 2      3   32217   42708   17921   25884   14050   14590       16384
#
#    TM_245_1  TM_585_1  TM_245_2  TM_585_2  Historical_1  TM_585_2096
# 0     58498     42829     59080     45039         78674        44989
# 1      2058      1423     11405     13556           289        13351
# 2     35255     51559     25326     37216         16910        38644

# %%
colors = [ '#E1E1E1', '#66CDAB', '#F86F64']

# %%
data = alldata["TM_585_2096"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('10 TM_585_2096.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
data = alldata["Historical_1"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('10 Historical.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
data = alldata["TM_245_1"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('11 TM_245_1.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
data = alldata["TM_245_2"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('12 TM_245_2.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
data = alldata["TM_585_1"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('13 TM_585_1.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
data = alldata["TM_585_2"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('14 TM_585_2.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
data = alldata["Historical"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('00 Historical.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
data = alldata["TM_245"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('01 TM_245.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
colors = [ '#E1E1E1', '#66CDAB', '#F86F64']

# %%
data = alldata["TM_585"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('02 TM_585.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
data = alldata["TN_245"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('03 TN_245.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
data = alldata["TN_585"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('04 TN_585.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
data = alldata["TX_245"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('05 TX_245.png', dpi=300,facecolor="none", transparent=True)
plt.show()

# %%
data = alldata["TX_585"]

# plt.rcParams["font.weight"] = "bold"
fig, axe = plt.subplots(figsize=(1, 1), dpi=300)
# 调整图片的边距
# plt.subplots_adjust(left=0.025, right=0.945, top=0.99, bottom=0.0009)
wedges, texts, autotexts= plt.pie(data,colors = colors,pctdistance = 1.2,autopct='%.0f%%')
plt.setp(texts, size=10, weight='bold', color='black')

plt.savefig('06 TX_585.png', dpi=300,facecolor="none", transparent=True)
plt.show()
